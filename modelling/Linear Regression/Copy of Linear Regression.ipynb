# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
filename = 'new_data.csv'
file = pd.read_csv(filename)
df = pd.DataFrame(file)
print(df)
# Out:
#     Route  Avg. 2011 Ridership  Avg. 2016 Ridership Ridership Change  \
# 0     BX1                38891                36487              -6%
# 1     BX2                38891                36487              -6%
# 2     BX3                15800                14921              -6%
# 3     BX4                12141                11411              -6%
# 4    BX4A                12141                11411              -6%
# ..    ...                  ...                  ...              ...
# 247   S92                 4923                 4431             -10%
# 248   S93                 1646                 3686             124%
# 249   S94                 6755                 7016               4%
# 250   S96                 7126                 7299               2%
# 251   S98                 7765                 7702              -1%
#
#      # of Stops  # of Stops near Subway        Borough
# 0          47.0                    19.0          Bronx
# 1          50.0                    18.0          Bronx
# 2          28.0                     3.0          Bronx
# 3          32.0                    16.0          Bronx
# 4          35.0                    13.0          Bronx
# ..          ...                     ...            ...
# 247        39.0                     0.0  Staten Island
# 248        21.0                     1.0  Staten Island
# 249        39.0                     0.0  Staten Island
# 250        38.0                     0.0  Staten Island
# 251        25.0                     0.0  Staten Island
#
# [252 rows x 7 columns]

# %%
x = np.array(df['# of Stops near Subway']).reshape(-1,1)
y = np.array(df['Avg. 2011 Ridership'])

# %%
plt.scatter(x, y)
plt.xlabel('# of stops')
plt.ylabel('Avg.Ridership')
plt.show()

# %%
model = LinearRegression().fit(x,y)

# %%
r_sq = model.score(x, y)
print(f"coefficient of determination: {r_sq}")
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
# Out:
# coefficient of determination: 0.07662269609399297
# intercept: 6497.736010898241
# slope: [377.97050997  57.97868148]

# %%
y_pred = model.predict(x)
print(f"predicted response:\n{y_pred}")
# Out:
# predicted response:
# [18634.41585034 18100.03452264 10084.31460704 17031.27186722
#  15428.1278841  10618.69593475 11687.45859016 12756.22124557
#  10618.69593475 13290.60257328 11153.07726245 11687.45859016
#  11687.45859016 11153.07726245  9549.93327933 14893.7465564
#  11153.07726245 12221.83991787 10084.31460704 16496.89053952
#  11153.07726245 12756.22124557 10084.31460704  9549.93327933
#  10618.69593475 10618.69593475 10618.69593475 13290.60257328
#   9015.55195163  9549.93327933  9549.93327933 13824.98390099
#  13290.60257328 10618.69593475 11153.07726245 11687.45859016
#  13290.60257328 14893.7465564  10618.69593475  9549.93327933
#   9549.93327933 10618.69593475  9549.93327933 14893.7465564
#   9015.55195163 11687.45859016 12221.83991787 12756.22124557
#  10618.69593475 13290.60257328 11153.07726245 11153.07726245
#  10618.69593475 15428.1278841  11153.07726245 11153.07726245
#  11687.45859016  9015.55195163 14893.7465564  12756.22124557
#  20771.94116117 15962.50921181  9015.55195163  9549.93327933
#  11153.07726245  9015.55195163  9015.55195163 14893.7465564
#   9015.55195163 14893.7465564   9015.55195163 11687.45859016
#  15428.1278841  11687.45859016 12221.83991787 12221.83991787
#   9015.55195163 11153.07726245 13824.98390099  9549.93327933
#  15428.1278841  12756.22124557 11153.07726245 15428.1278841
#  13290.60257328 13824.98390099 10618.69593475 10084.31460704
#  10618.69593475 14359.36522869 11687.45859016 12221.83991787
